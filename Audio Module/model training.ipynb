# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, LSTM, Dense, BatchNormalization, Bidirectional
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# === Constants
max_len = 130
num_features_per_timestep = 13  # Number of MFCC features per timestep

# === Step 1: Load dataset
df = pd.read_csv("ravdess_all_actors_full_mfcc.csv")
df = df[df["emotion"] != "unknown"].reset_index(drop=True)

# === Step 2: Prepare features and labels
feature_columns = [col for col in df.columns if col.startswith("mfcc_")]
X = df[feature_columns].values
y = df['emotion'].values

# === Step 3: Encode labels
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# === Step 4: Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print("Shape of X before scaling:", X.shape)
print("Expected: num_samples × num_features")


# === Step 5: Reshape input to (samples, timesteps, features)

X_reshaped = X_scaled.reshape(X_scaled.shape[0], 130, 13)


# === Step 6: Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, y_categorical, test_size=0.2, random_state=42, stratify=y_encoded
)

# === Step 7: Class Weights
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_encoded), y=y_encoded)
class_weights = dict(enumerate(class_weights))

# === Step 8: CNN + BiLSTM Model
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(max_len, num_features_per_timestep)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Bidirectional(LSTM(64, return_sequences=False)))
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# === Step 9: Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
]

# === Step 10: Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)

# === Step 11: Save model and label encoder
model.save("speech_emotion_cnn_bilstm.h5")
encoder_df = pd.DataFrame({'label': encoder.classes_})
encoder_df.to_csv("label_encoder.csv", index=False)

print("✅ Model saved as speech_emotion_cnn_bilstm.h5")
# Out:
# Shape of X before scaling: (2880, 1690)
# Expected: num_samples × num_features
# Epoch 1/100
# Epoch 1/100
# 72/72 [==============================] - 13s 89ms/step - loss: 1.8636 - accuracy: 0.2457 - val_loss: 1.7225 - val_accuracy: 0.3420 - lr: 0.0010
# Epoch 2/100
# 72/72 [==============================] - 13s 89ms/step - loss: 1.8636 - accuracy: 0.2457 - val_loss: 1.7225 - val_accuracy: 0.3420 - lr: 0.0010
# Epoch 2/100
# 72/72 [==============================] - 5s 64ms/step - loss: 1.6587 - accuracy: 0.3429 - val_loss: 1.5961 - val_accuracy: 0.3819 - lr: 0.0010
# Epoch 3/100
# 72/72 [==============================] - 5s 64ms/step - loss: 1.6587 - accuracy: 0.3429 - val_loss: 1.5961 - val_accuracy: 0.3819 - lr: 0.0010
# Epoch 3/100
# 72/72 [==============================] - 4s 60ms/step - loss: 1.5500 - accuracy: 0.4041 - val_loss: 1.4203 - val_accuracy: 0.4635 - lr: 0.0010
# Epoch 4/100
# 72/72 [==============================] - 4s 60ms/step - loss: 1.5500 - accuracy: 0.4041 - val_loss: 1.4203 - val_accuracy: 0.4635 - lr: 0.0010
# Epoch 4/100
# 72/72 [==============================] - 5s 65ms/step - loss: 1.4517 - accuracy: 0.4397 - val_loss: 1.3225 - val_accuracy: 0.4983 - lr: 0.0010
# Epoch 5/100
# 72/72 [==============================] - 5s 65ms/step - loss: 1.4517 - accuracy: 0.4397 - val_loss: 1.3225 - val_accuracy: 0.4983 - lr: 0.0010
# Epoch 5/100
# 72/72 [==============================] - 5s 70ms/step - loss: 1.3668 - accuracy: 0.4709 - val_loss: 1.2753 - val_accuracy: 0.5174 - lr: 0.0010
# Epoch 6/100
# 72/72 [==============================] - 5s 70ms/step - loss: 1.3668 - accuracy: 0.4709 - val_loss: 1.2753 - val_accuracy: 0.5174 - lr: 0.0010
# Epoch 6/100
# 72/72 [==============================] - 4s 62ms/step - loss: 1.2873 - accuracy: 0.5117 - val_loss: 1.2114 - val_accuracy: 0.5226 - lr: 0.0010
# Epoch 7/100
# 72/72 [==============================] - 4s 62ms/step - loss: 1.2873 - accuracy: 0.5117 - val_loss: 1.2114 - val_accuracy: 0.5226 - lr: 0.0010
# Epoch 7/100
# 72/72 [==============================] - 6s 80ms/step - loss: 1.1987 - accuracy: 0.5417 - val_loss: 1.1778 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 8/100
# 72/72 [==============================] - 6s 80ms/step - loss: 1.1987 - accuracy: 0.5417 - val_loss: 1.1778 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 8/100
# 72/72 [==============================] - 6s 86ms/step - loss: 1.1209 - accuracy: 0.5755 - val_loss: 1.0900 - val_accuracy: 0.5816 - lr: 0.0010
# Epoch 9/100
# 72/72 [==============================] - 6s 86ms/step - loss: 1.1209 - accuracy: 0.5755 - val_loss: 1.0900 - val_accuracy: 0.5816 - lr: 0.0010
# Epoch 9/100
# 72/72 [==============================] - 5s 70ms/step - loss: 1.0302 - accuracy: 0.5990 - val_loss: 1.1033 - val_accuracy: 0.5608 - lr: 0.0010
# Epoch 10/100
# 72/72 [==============================] - 5s 70ms/step - loss: 1.0302 - accuracy: 0.5990 - val_loss: 1.1033 - val_accuracy: 0.5608 - lr: 0.0010
# Epoch 10/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.9957 - accuracy: 0.6146 - val_loss: 1.0125 - val_accuracy: 0.6215 - lr: 0.0010
# Epoch 11/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.9957 - accuracy: 0.6146 - val_loss: 1.0125 - val_accuracy: 0.6215 - lr: 0.0010
# Epoch 11/100
# 72/72 [==============================] - 5s 72ms/step - loss: 0.8856 - accuracy: 0.6701 - val_loss: 0.9766 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 12/100
# 72/72 [==============================] - 5s 72ms/step - loss: 0.8856 - accuracy: 0.6701 - val_loss: 0.9766 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 12/100
# 72/72 [==============================] - 5s 76ms/step - loss: 0.8687 - accuracy: 0.6671 - val_loss: 0.9320 - val_accuracy: 0.6632 - lr: 0.0010
# Epoch 13/100
# 72/72 [==============================] - 5s 76ms/step - loss: 0.8687 - accuracy: 0.6671 - val_loss: 0.9320 - val_accuracy: 0.6632 - lr: 0.0010
# Epoch 13/100
# 72/72 [==============================] - 5s 68ms/step - loss: 0.7684 - accuracy: 0.7040 - val_loss: 0.8985 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 14/100
# 72/72 [==============================] - 5s 68ms/step - loss: 0.7684 - accuracy: 0.7040 - val_loss: 0.8985 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 14/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.7568 - accuracy: 0.7174 - val_loss: 0.8397 - val_accuracy: 0.6997 - lr: 0.0010
# Epoch 15/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.7568 - accuracy: 0.7174 - val_loss: 0.8397 - val_accuracy: 0.6997 - lr: 0.0010
# Epoch 15/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.6841 - accuracy: 0.7513 - val_loss: 0.7457 - val_accuracy: 0.7517 - lr: 0.0010
# Epoch 16/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.6841 - accuracy: 0.7513 - val_loss: 0.7457 - val_accuracy: 0.7517 - lr: 0.0010
# Epoch 16/100
# 72/72 [==============================] - 5s 66ms/step - loss: 0.6334 - accuracy: 0.7639 - val_loss: 0.7200 - val_accuracy: 0.7726 - lr: 0.0010
# Epoch 17/100
# 72/72 [==============================] - 5s 66ms/step - loss: 0.6334 - accuracy: 0.7639 - val_loss: 0.7200 - val_accuracy: 0.7726 - lr: 0.0010
# Epoch 17/100
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6168 - accuracy: 0.7682 - val_loss: 0.7068 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 18/100
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6168 - accuracy: 0.7682 - val_loss: 0.7068 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 18/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5321 - accuracy: 0.7973 - val_loss: 0.6773 - val_accuracy: 0.8056 - lr: 0.0010
# Epoch 19/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5321 - accuracy: 0.7973 - val_loss: 0.6773 - val_accuracy: 0.8056 - lr: 0.0010
# Epoch 19/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.5148 - accuracy: 0.8121 - val_loss: 0.6905 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 20/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.5148 - accuracy: 0.8121 - val_loss: 0.6905 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 20/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5006 - accuracy: 0.8129 - val_loss: 0.6568 - val_accuracy: 0.7986 - lr: 0.0010
# Epoch 21/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5006 - accuracy: 0.8129 - val_loss: 0.6568 - val_accuracy: 0.7986 - lr: 0.0010
# Epoch 21/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.4350 - accuracy: 0.8411 - val_loss: 0.6053 - val_accuracy: 0.8247 - lr: 0.0010
# Epoch 22/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.4350 - accuracy: 0.8411 - val_loss: 0.6053 - val_accuracy: 0.8247 - lr: 0.0010
# Epoch 22/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4350 - accuracy: 0.8364 - val_loss: 0.5490 - val_accuracy: 0.8455 - lr: 0.0010
# Epoch 23/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4350 - accuracy: 0.8364 - val_loss: 0.5490 - val_accuracy: 0.8455 - lr: 0.0010
# Epoch 23/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.3872 - accuracy: 0.8581 - val_loss: 0.6012 - val_accuracy: 0.8194 - lr: 0.0010
# Epoch 24/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.3872 - accuracy: 0.8581 - val_loss: 0.6012 - val_accuracy: 0.8194 - lr: 0.0010
# Epoch 24/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.3817 - accuracy: 0.8594 - val_loss: 0.5200 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 25/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.3817 - accuracy: 0.8594 - val_loss: 0.5200 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 25/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.3788 - accuracy: 0.8516 - val_loss: 0.5056 - val_accuracy: 0.8663 - lr: 0.0010
# Epoch 26/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.3788 - accuracy: 0.8516 - val_loss: 0.5056 - val_accuracy: 0.8663 - lr: 0.0010
# Epoch 26/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.3566 - accuracy: 0.8698 - val_loss: 0.4911 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 27/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.3566 - accuracy: 0.8698 - val_loss: 0.4911 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 27/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.3350 - accuracy: 0.8767 - val_loss: 0.5752 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 28/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.3350 - accuracy: 0.8767 - val_loss: 0.5752 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 28/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.3033 - accuracy: 0.8932 - val_loss: 0.4751 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 29/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.3033 - accuracy: 0.8932 - val_loss: 0.4751 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 29/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.3251 - accuracy: 0.8832 - val_loss: 0.5398 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 30/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.3251 - accuracy: 0.8832 - val_loss: 0.5398 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 30/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.2925 - accuracy: 0.8924 - val_loss: 0.4995 - val_accuracy: 0.8681 - lr: 0.0010
# Epoch 31/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.2925 - accuracy: 0.8924 - val_loss: 0.4995 - val_accuracy: 0.8681 - lr: 0.0010
# Epoch 31/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.2465 - accuracy: 0.9119 - val_loss: 0.4801 - val_accuracy: 0.8733 - lr: 0.0010
# Epoch 32/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.2465 - accuracy: 0.9119 - val_loss: 0.4801 - val_accuracy: 0.8733 - lr: 0.0010
# Epoch 32/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.2849 - accuracy: 0.9006 - val_loss: 0.4976 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 33/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.2849 - accuracy: 0.9006 - val_loss: 0.4976 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 33/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.2558 - accuracy: 0.9089 - val_loss: 0.5300 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 34/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.2558 - accuracy: 0.9089 - val_loss: 0.5300 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 34/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.2393 - accuracy: 0.9171 - val_loss: 0.4898 - val_accuracy: 0.8785 - lr: 5.0000e-04
# Epoch 35/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.2393 - accuracy: 0.9171 - val_loss: 0.4898 - val_accuracy: 0.8785 - lr: 5.0000e-04
# Epoch 35/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.2034 - accuracy: 0.9293 - val_loss: 0.4866 - val_accuracy: 0.8872 - lr: 5.0000e-04
# Epoch 36/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.2034 - accuracy: 0.9293 - val_loss: 0.4866 - val_accuracy: 0.8872 - lr: 5.0000e-04
# Epoch 36/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.1741 - accuracy: 0.9327 - val_loss: 0.4741 - val_accuracy: 0.8854 - lr: 5.0000e-04
# Epoch 37/100
# 72/72 [==============================] - 4s 62ms/step - loss: 0.1741 - accuracy: 0.9327 - val_loss: 0.4741 - val_accuracy: 0.8854 - lr: 5.0000e-04
# Epoch 37/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.2044 - accuracy: 0.9253 - val_loss: 0.4649 - val_accuracy: 0.8872 - lr: 5.0000e-04
# Epoch 38/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.2044 - accuracy: 0.9253 - val_loss: 0.4649 - val_accuracy: 0.8872 - lr: 5.0000e-04
# Epoch 38/100
# 72/72 [==============================] - 5s 67ms/step - loss: 0.1856 - accuracy: 0.9332 - val_loss: 0.4736 - val_accuracy: 0.8924 - lr: 5.0000e-04
# Epoch 39/100
# 72/72 [==============================] - 5s 67ms/step - loss: 0.1856 - accuracy: 0.9332 - val_loss: 0.4736 - val_accuracy: 0.8924 - lr: 5.0000e-04
# Epoch 39/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1730 - accuracy: 0.9414 - val_loss: 0.4814 - val_accuracy: 0.8889 - lr: 5.0000e-04
# Epoch 40/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1730 - accuracy: 0.9414 - val_loss: 0.4814 - val_accuracy: 0.8889 - lr: 5.0000e-04
# Epoch 40/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1667 - accuracy: 0.9371 - val_loss: 0.4665 - val_accuracy: 0.9028 - lr: 5.0000e-04
# Epoch 41/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1667 - accuracy: 0.9371 - val_loss: 0.4665 - val_accuracy: 0.9028 - lr: 5.0000e-04
# Epoch 41/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1887 - accuracy: 0.9288 - val_loss: 0.5068 - val_accuracy: 0.8906 - lr: 5.0000e-04
# Epoch 42/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1887 - accuracy: 0.9288 - val_loss: 0.5068 - val_accuracy: 0.8906 - lr: 5.0000e-04
# Epoch 42/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.1533 - accuracy: 0.9457 - val_loss: 0.4823 - val_accuracy: 0.8906 - lr: 5.0000e-04
# Epoch 43/100
# 72/72 [==============================] - 5s 64ms/step - loss: 0.1533 - accuracy: 0.9457 - val_loss: 0.4823 - val_accuracy: 0.8906 - lr: 5.0000e-04
# Epoch 43/100
# 72/72 [==============================] - 5s 67ms/step - loss: 0.1430 - accuracy: 0.9527 - val_loss: 0.4576 - val_accuracy: 0.8958 - lr: 2.5000e-04
# Epoch 44/100
# 72/72 [==============================] - 5s 67ms/step - loss: 0.1430 - accuracy: 0.9527 - val_loss: 0.4576 - val_accuracy: 0.8958 - lr: 2.5000e-04
# Epoch 44/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1329 - accuracy: 0.9540 - val_loss: 0.4698 - val_accuracy: 0.8941 - lr: 2.5000e-04
# Epoch 45/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1329 - accuracy: 0.9540 - val_loss: 0.4698 - val_accuracy: 0.8941 - lr: 2.5000e-04
# Epoch 45/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1374 - accuracy: 0.9527 - val_loss: 0.4399 - val_accuracy: 0.8993 - lr: 2.5000e-04
# Epoch 46/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1374 - accuracy: 0.9527 - val_loss: 0.4399 - val_accuracy: 0.8993 - lr: 2.5000e-04
# Epoch 46/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1368 - accuracy: 0.9549 - val_loss: 0.4646 - val_accuracy: 0.8924 - lr: 2.5000e-04
# Epoch 47/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1368 - accuracy: 0.9549 - val_loss: 0.4646 - val_accuracy: 0.8924 - lr: 2.5000e-04
# Epoch 47/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1343 - accuracy: 0.9501 - val_loss: 0.4806 - val_accuracy: 0.8906 - lr: 2.5000e-04
# Epoch 48/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1343 - accuracy: 0.9501 - val_loss: 0.4806 - val_accuracy: 0.8906 - lr: 2.5000e-04
# Epoch 48/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1346 - accuracy: 0.9540 - val_loss: 0.4704 - val_accuracy: 0.8958 - lr: 2.5000e-04
# Epoch 49/100
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1346 - accuracy: 0.9540 - val_loss: 0.4704 - val_accuracy: 0.8958 - lr: 2.5000e-04
# Epoch 49/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1183 - accuracy: 0.9614 - val_loss: 0.4673 - val_accuracy: 0.8976 - lr: 2.5000e-04
# Epoch 50/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1183 - accuracy: 0.9614 - val_loss: 0.4673 - val_accuracy: 0.8976 - lr: 2.5000e-04
# Epoch 50/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1250 - accuracy: 0.9596 - val_loss: 0.5012 - val_accuracy: 0.8906 - lr: 2.5000e-04
# Epoch 51/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1250 - accuracy: 0.9596 - val_loss: 0.5012 - val_accuracy: 0.8906 - lr: 2.5000e-04
# Epoch 51/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1169 - accuracy: 0.9596 - val_loss: 0.4762 - val_accuracy: 0.8889 - lr: 1.2500e-04
# Epoch 52/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1169 - accuracy: 0.9596 - val_loss: 0.4762 - val_accuracy: 0.8889 - lr: 1.2500e-04
# Epoch 52/100
# 72/72 [==============================] - 5s 66ms/step - loss: 0.1187 - accuracy: 0.9588 - val_loss: 0.4746 - val_accuracy: 0.8958 - lr: 1.2500e-04
# Epoch 53/100
# 72/72 [==============================] - 5s 66ms/step - loss: 0.1187 - accuracy: 0.9588 - val_loss: 0.4746 - val_accuracy: 0.8958 - lr: 1.2500e-04
# Epoch 53/100
# 72/72 [==============================] - 5s 66ms/step - loss: 0.1242 - accuracy: 0.9566 - val_loss: 0.4817 - val_accuracy: 0.8889 - lr: 1.2500e-04
# Epoch 54/100
# 72/72 [==============================] - 5s 66ms/step - loss: 0.1242 - accuracy: 0.9566 - val_loss: 0.4817 - val_accuracy: 0.8889 - lr: 1.2500e-04
# Epoch 54/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1123 - accuracy: 0.9588 - val_loss: 0.4775 - val_accuracy: 0.8993 - lr: 1.2500e-04
# Epoch 55/100
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1123 - accuracy: 0.9588 - val_loss: 0.4775 - val_accuracy: 0.8993 - lr: 1.2500e-04
# Epoch 55/100
# 72/72 [==============================] - 5s 72ms/step - loss: 0.1225 - accuracy: 0.9570 - val_loss: 0.4698 - val_accuracy: 0.8958 - lr: 1.2500e-04
# 72/72 [==============================] - 5s 72ms/step - loss: 0.1225 - accuracy: 0.9570 - val_loss: 0.4698 - val_accuracy: 0.8958 - lr: 1.2500e-04
# ✅ Model saved as speech_emotion_cnn_bilstm.h5
# ✅ Model saved as speech_emotion_cnn_bilstm.h5

# %%
import pickle
#...existing code...
# After fitting encoder and scaler, save them for use in testing
with open("label_encoder.pkl", "wb") as f:
    pickle.dump(encoder, f)
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training History')
plt.legend()
plt.grid(True)
plt.show()

# %%
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {acc * 100:.2f}%")

from sklearn.metrics import classification_report
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print(classification_report(y_true_classes, y_pred_classes, target_names=encoder.classes_))
# Out:
# 18/18 [==============================] - 0s 22ms/step - loss: 0.4399 - accuracy: 0.8993
# 18/18 [==============================] - 0s 22ms/step - loss: 0.4399 - accuracy: 0.8993
# Test Accuracy: 89.93%
# Test Accuracy: 89.93%
# 18/18 [==============================] - 2s 18ms/step
# 18/18 [==============================] - 2s 18ms/step
#               precision    recall  f1-score   support
#
#        angry       0.83      0.92      0.88        76
#         calm       0.86      0.92      0.89        77
#      disgust       0.90      0.90      0.90        77
#      fearful       0.94      0.87      0.91        77
#        happy       0.87      0.90      0.88        77
#      neutral       1.00      1.00      1.00        38
#          sad       0.91      0.79      0.85        77
#    surprised       0.95      0.95      0.95        77
#
#     accuracy                           0.90       576
#    macro avg       0.91      0.91      0.91       576
# weighted avg       0.90      0.90      0.90       576
#
#               precision    recall  f1-score   support
#
#        angry       0.83      0.92      0.88        76
#         calm       0.86      0.92      0.89        77
#      disgust       0.90      0.90      0.90        77
#      fearful       0.94      0.87      0.91        77
#        happy       0.87      0.90      0.88        77
#      neutral       1.00      1.00      1.00        38
#          sad       0.91      0.79      0.85        77
#    surprised       0.95      0.95      0.95        77
#
#     accuracy                           0.90       576
#    macro avg       0.91      0.91      0.91       576
# weighted avg       0.90      0.90      0.90       576
